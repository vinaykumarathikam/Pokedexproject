# %%
import numpy as np
import pandas as pd

# %%
arr = np.array([1,2,3])
arr
# Out:
# array([1, 2, 3])

# %%
import tensorflow

# %%
import os
import matplotlib.pyplot as plt

# %%
path = '../images/images'
images = os.listdir(path)

# %%
images
# Out:
# []

# %%
import matplotlib.image as mpimg

# %%
images
# Out:
# []

# %%
# Directory
directory = "Images"
# Path
path = os.path.join(directory)
os.mkdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In [9], line 5
#       3 # Path
#       4 path = os.path.join(directory)
# ----> 5 os.mkdir(path)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Images'

# %%
path = './Images'
images[0]

# %% [markdown]
# # Creating the files of each Pokemon

# %%
path = './Images'
for i in range (len(images)):
    li = images[i].split('.')
    dir_name = li[0]
    path2 = os.path.join(path,dir_name)
    os.mkdir(path2)

# %% [markdown]
# # Transfer images

# %%
s_path = '../images/images'
d_path = './Images'
for i in range (len(images)):
    source_path = os.path.join(s_path,images[i])
    li = images[i].split('.')
    dir_name = li[0]
    dest_path = os.path.join(d_path,dir_name,images[i])
    os.rename(source_path,dest_path)

# %%
s_path = '../images/images'
s_path

# %%
images = os.listdir('./Images')
images

# %%
pikachu_path = os.listdir('./Images/pikachu')
pikachu_path

# %%
import PIL

# %%
import cv2

# %%
PIL.Image.open(str('./Images/pikachu/pikachu.png'))

# %%
root = './Images'
pokemon_image_dict = {}
for i in images:
    path1 = os.path.join(root,i)
    poke_path = os.listdir(path1)
    tot_path = os.path.join(path1,poke_path[0])
    pokemon_image_dict[i] = tot_path
pokemon_image_dict

# %%
PIL.Image.open(str(pokemon_image_dict['charmander']))

# %%
pokemon_label_dict = {}
c = 0
for i in images:
    pokemon_label_dict[i] = c
    c+=1
pokemon_label_dict

# %%
img = cv2.imread(str(pokemon_image_dict['axew']))
img.shape

# %%
X,y = [], []
for poke_name,pictures in pokemon_image_dict.items():
    img = cv2.imread(pictures)
    img = cv2.resize(img,(224,224),3)
    X.append(img)
    y.append(pokemon_label_dict[poke_name])

# %%
X = np.array(X)
y = np.array(y)
type(X)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
import keras.utils
from tensorflow.keras import layers

# %%
data_augmentation = keras.Sequential(
  [

    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
data_augmentation(X)[0]

# %%
plt.imshow(data_augmentation(X)[10].numpy().astype("uint8"))

# %%
plt.imshow(X[10])

# %%
plt.imshow(data_augmentation(X[0]).numpy().astype("uint8"))

# %%
type(X)

# %%
X_train = X / 255

# %%
len(X)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from keras.models import Sequential
from keras.layers import Conv2D,BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense, Activation,GlobalMaxPooling2D
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.applications.mobilenet import MobileNet
from keras.models import Model

# %%
import tensorflow_hub as hub

# %%
feature_extractor_model = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"

pretrained_model_without_top_layer = hub.KerasLayer(
    feature_extractor_model, input_shape=(224, 224, 3), trainable=False)

# %%
num_of_pokemons = 809

model = tf.keras.Sequential([
  data_augmentation,
  pretrained_model_without_top_layer,
  tf.keras.layers.Dense(num_of_pokemons)
])

# %%
model.compile(
  optimizer="adam",
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])

model.fit(X_train, y, epochs=5)
# Out:
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (224, 224, 3) for input KerasTensor(type_spec=TensorSpec(shape=(224, 224, 3), dtype=tf.uint8, name='random_rotation_3_input'), name='random_rotation_3_input', description="created by layer 'random_rotation_3_input'"), but it was called on an input with incompatible shape (None, 224, 224, 3).
# WARNING:tensorflow:Model was constructed with shape (224, 224, 3) for input KerasTensor(type_spec=TensorSpec(shape=(224, 224, 3), dtype=tf.uint8, name='random_rotation_3_input'), name='random_rotation_3_input', description="created by layer 'random_rotation_3_input'"), but it was called on an input with incompatible shape (None, 224, 224, 3).
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# ...

# %%
image1 = mpimg.imread("./Images/pikachu/charmander.png")
plt.imshow(image1)
#plt.show()
image1 = cv2.resize(image1,(224,224),3)
pika1 = np.array(image1)/255.0
image1.shape
#pika1.shape
#pika1[np.newaxis,...].shape

# %%
plt.imshow(X[0])

# %%
X[0].shape

# %%
poke1 = X[0]

# %%
poke1.shape
poke1[np.newaxis,...].shape
# Out:
# (1, 224, 224, 3)

# %%
res1 = model.predict(poke1[np.newaxis,...])
predicted_label_index1 = np.argmax(res1)
predicted_label_index1
# Out:
# WARNING:tensorflow:Model was constructed with shape (224, 224, 3) for input KerasTensor(type_spec=TensorSpec(shape=(224, 224, 3), dtype=tf.uint8, name='random_rotation_3_input'), name='random_rotation_3_input', description="created by layer 'random_rotation_3_input'"), but it was called on an input with incompatible shape (None, 224, 224, 3).
# WARNING:tensorflow:Model was constructed with shape (224, 224, 3) for input KerasTensor(type_spec=TensorSpec(shape=(224, 224, 3), dtype=tf.uint8, name='random_rotation_3_input'), name='random_rotation_3_input', description="created by layer 'random_rotation_3_input'"), but it was called on an input with incompatible shape (None, 224, 224, 3).
# 1/1 [==============================] - 2s 2s/step
# 437

# %%
image1 = mpimg.imread("./download1.jpg")
plt.imshow(image1)
#plt.show()
image1 = cv2.resize(image1,(224,224),3)
pika1 = np.array(image1)/255.0
image1.shape
#pika1.shape
pika1[np.newaxis,...].shape

# %%
res1 = model.predict(pika1[np.newaxis,...])
predicted_label_index1 = np.argmax(res1)
predicted_label_index1

# %%
for name,ind in pokemon_label_dict.items():
    if(ind == 719):
        print(name)
        break

# %%
res1 = model.predict(pika1[np.newaxis,...])
predicted_label_index1 = np.argmax(res1)
predicted_label_index1

# %%
image1 = mpimg.imread("./abas.jpg")
plt.imshow(image1)
#plt.show()
image1 = cv2.resize(image1,(224,224),3)
pika1 = np.array(image1)/255.0
image1.shape
#pika1.shape
pika1[np.newaxis,...].shape

# %%
res1 = model.predict(pika1[np.newaxis,...])
predicted_label_index1 = np.argmax(res1)
predicted_label_index1

# %%
for name,ind in pokemon_label_dict.items():
    if(ind == 263):
        print(name)
        break

# %%
golisopod_path = os.listdir('./Images/golisopod')

# %%
import PIL

# %%
PIL.Image.open(str('./Images/golisopod/golisopod.jpg'))

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.22, random_state=0)

# %%
len(X_train)
#len(X_test)
# Out:
# 631

# %%
y_train[10]

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
model.compile(
  optimizer="adam",
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])

model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/5
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# ...

# %%
poke1 = X[0]
poke1.shape
poke1[np.newaxis,...].shape
res1 = model.predict(poke1[np.newaxis,...])
predicted_label_index1 = np.argmax(res1)
predicted_label_index1
# Out:
# 1/1 [==============================] - 1s 1s/step
# 0

# %%
model.evaluate(X_test,y_test)
# Out:
# 6/6 [==============================] - 6s 688ms/step - loss: 15.0858 - acc: 0.0000e+00
# [15.085845947265625, 0.0]
